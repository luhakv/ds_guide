# %% [markdown]
# ## Юнит 9. Профориентация в Data Science
# ### Skillfactory: DSPR-19
# ### Модуль 2. Знакомство с CV

# %% [markdown]
# ### 1. Введение
# → Пришло время познакомиться с каждым из направлений в отдельности. И первый на очереди — CV Engineer.
#
# CV-инженер берёт на себя все ML задачи, связанные с обработкой изображений и видео. Значит, нам нужно знать, как преобразовывать эти данные в признаки, с которыми можно работать классическими методами ML. Но, кроме этого, конечно, более десяти лет в CV развиваются нейросети, ставшие неотъемлемым инструментом в решении задач компьютерного зрения.
#
# Для начала давайте познакомимся с автором модуля:
#
#
# Всем привет!
#
# Меня зовут Андрей Казначеев, я работаю в совместной лаборатории МФТИ и Россельхозбанка CV- и NLP-разработчиком. Моя команда помогает банку сэкономить деньги, автоматизируя многие процессы с помощью искусственного интеллекта.
#
# Что вы узнаете в этом модуле:
#
# какие задачи решает CV Engineer;
# как жили люди и решали задачи до появления нейросетей;
# какие инструменты используются в CV и как они работают;
# с помощью каких приёмов можно облегчить себе работу и получить лучшие результаты.
# И, конечно же, вы попрактикуетесь в решении одной из классических задач компьютерного зрения.
#
# Поехали! ⭐

# %% [markdown]
# ### 2. Классические задачи CV
# → Начнём с небольшого обзора основной области применения компьютерного зрения. Существует широкий спектр разнообразных задач, которые хорошо решаются с помощью алгоритмов CV, условно их можно разделить на три основных типа: классические задачи, генеративные задачи и CV в 3D.
#
# Сначала давайте остановимся на классических задачах.
#
# ### КЛАССИФИКАЦИЯ
#
# Из курса «Введение в DL» вы уже имеете представление, что такое нейросети, поэтому предлагаем освежить свои воспоминания, выполнив небольшой тест ↓

# %% [markdown]
# ### Задание 2.1
# Нейросети какой архитектуры лучше всего подходят для работы с изображениями?
#
# Ответ: Сверточные

# %% [markdown]
# ### Задание 2.2
#
# Сопоставьте задачи с основными методами их решения
#
# Ответ:
# - Генерация изображений - GAN (Generative Adversarial Nets)
# - Классификация изображений - CNN (Convolutional Neural Nets)
# - генерация текста - RNN (Recurrent Neural Nets)

# %% [markdown]
# Итак, мы вспомнили, что для работы с изображениями лучше всего подходят свёрточные нейронные сети. Подробно принцип их работы мы рассмотрим в одном из следующих модулей. Сейчас же хочется рассказать, почему свёртка — это основа компьютерного зрения, и показать, что в наших задачах она действительно работает лучше классических сетей.
#
# В 90-е годы нейросети в компьютерном зрении «выстрелили». Первый яркий результат они дали в задаче классификации рукописных цифр (ныне широко известный датасет MNIST). И так уж сложилось, что именно задача классификации стала основой при решении почти любой задачи в CV.
#
# Пример рукописных цифр из датасета MNIST
# После проведения ряда экспериментов по решению задачи распознавания рукописных цифр был сделан вывод, что свёрточные нейронные сети имеют большое преимущество перед обычными сетями. В частности, сравнили качество решения этой задачи с использованием простой нейронной сети, сети с одним скрытым слоем различной размерности и простейшими свёрточными сетями. Архитектура сетей представлена на изображениях ниже.
#
# Простая нейронная сеть
#
# Нейронная сеть со скрытым слоем
#
# Архитектура простейшей свёрточной сети

# %% [markdown]
# Как мы видим из этой таблицы, даже простая свёрточная сеть, у которой в 80 раз меньше коэффициентов, выдаёт качество на ~1% лучше, чем обычная сеть, затрачивая на это меньше вычислительных мощностей.
#
# Архитектура свёрточной сети выглядит громоздко, но вот как это реализовано с точки зрения кода:

# %%
Image(url= "http://my_site.com/my_picture.jpg")
# Out:
# img/dspr-prof-md3-2_7.png

# %% [markdown]
# Как видите, ничего страшного здесь нет: всего 11 строчек кода занимает модель, способная классифицировать рукописные цифры.
